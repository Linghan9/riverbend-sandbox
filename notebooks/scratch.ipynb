# %%
import sys
sys.path.insert(0, "..")
from src.clean import parse_currency

parse_currency("42.00")

# %%
value = "42.00"
c = "" if value is None else str(value).replace("$", "").replace(",", "")
print(repr(c))
# Out:
# '42.00'

# %%
import re
m = re.match(r"^[-+]?\d*\.?\d+", "7.20 mmol/L")
print(m)
# Out:
# <re.Match object; span=(0, 4), match='7.20'>

# %%
import pandas as pd 
billing = pd.read_csv("../data/raw/billing.csv")

df1 = billing["encounter_id"].unique()
df2 = encounters["encounter_id"].unique()

print(df1)
# Out:
# <StringArray>
# ['ENC0006301', 'ENC0004014', 'ENC0000670', 'ENC0002873', 'ENC0002980',
#  'ENC0005216', 'ENC0001472', 'ENC0000345', 'ENC0003269', 'ENC0000913',
#  ...
#  'ENC0000396', 'ENC0003854', 'ENC0000351', 'ENC0004158', 'ENC0006129',
#  'ENC0002275', 'ENC0006493', 'ENC0000325', 'ENC0001718', 'ENC0005710']
# Length: 6451, dtype: str
